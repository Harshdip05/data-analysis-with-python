# %% [markdown]
# ### Numpy array vs Python lists

# %%
a = [1,2,3]
b = [4,5,6]
print(a+b)
# it combines lists, not mathematical addition

# to add numbers element-wise, you must use a loop or comprehension
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# time

a = [i for i in range(10000000)]
b = [i for i in range(10000000,20000000)]

c = []
import time 
start = time.time()

for i in range(len(a)):
    c.append(a[i]+b[i])

end = time.time() - start    
print(end)
# Out:
# 3.7659144401550293

# %%
import numpy as np

a = np.arange(10000000)
b = np.arange(10000000,20000000)

start = time.time()
c = a+b
end = time.time() - start
print(end)
# Out:
# 0.10633707046508789

# %%
3.5155029296875/0.10633707046508789   ## 33 times numpy is faster than list
# Out:
# 33.059994170534296

# %%
# memory

a = [i for i in range(10000000)]
import sys

print(sys.getsizeof(a))
# Out:
# 89095160

# %%
a = np.arange(10000000)
print(sys.getsizeof(a))
# Out:
# 80000112

# %%
a1 = np.arange(10000000,dtype=np.int32)
print(sys.getsizeof(a1))
# Out:
# 40000112

# %%
a1 = np.arange(10000000,dtype=np.int16)
print(sys.getsizeof(a1))
# Out:
# 20000112

# %%
a1 = np.arange(10000000,dtype=np.int8)
print(sys.getsizeof(a1))
# Out:
# 10000112

# %%
# convenience

# %% [markdown]
# ### Advanced Indexing

# %%
# Normal indexing and slicing

# %%
# Fancy indexing

# %%
# Boolean indexing

# %% [markdown]
# ### Broadcasting
#
# The term broadcasting describes how NumPy treats arrays with different shapes during arithmetic operations.
#
# The smaller array is “broadcast” across the larger array so that they have compatible shapes.

# %% [markdown]
# #### Broadcasting Rules
#
# **1. Make the two arrays have the same number of dimensions.**<br>
# - If the numbers of dimensions of the two arrays are different, add new dimensions with size 1 to the head of the array with the smaller dimension.<br>

# %% [markdown]
# **2. Make each dimension of the two arrays the same size.**<br>
#
# ---
#
#
# - If the sizes of each dimension of the two arrays do not match, dimensions with size 1 are stretched to the size of the other array.
# - If there is a dimension whose size is not 1 in either of the two arrays, it cannot be broadcasted, and an error is raised.

# %% [markdown]
# <img src = "https://jakevdp.github.io/PythonDataScienceHandbook/figures/02.05-broadcasting.png">

# %% [markdown]
# ### Working with mathematical formulas
